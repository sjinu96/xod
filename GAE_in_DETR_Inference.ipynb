# %% [markdown]
# ## Implementation code for "Generic Attention-model Explainability for Interpreting Bi-Modal and Encoder-Decoder Transformers"

# %%
import os

# %% [markdown]
# 작업폴더 설정

# %%
os.chdir('Transformer-MM-Explainability')

# %%
# !pip install -r requirements.txt

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt
import numpy as np

# from DETR.datasets.coco import *
import torch
import torchvision.transforms as T
import os
import random
import cv2
import DETR.util.misc as utils

from DETR.models import build_model
from DETR.modules.ExplanationGenerator import Generator
import argparse

# %% [markdown]
# **Auxilary functions**

# %%
class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

# %%
# COCO classes
CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]


# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{CLASSES[cl]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
# !pip install ipywidgets

# %%
import ipywidgets

# %%
device='cuda'
args = Namespace(aux_loss=True, backbone='resnet50', batch_size=1, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, coco_path=None, dataset_file='coco', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=300, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=100, num_workers=2, output_dir='', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)

model, criterion, postprocessors = build_model(args)
model.to(device)

checkpoint=torch.hub.load_state_dict_from_url(
args.resume, map_location='cpu', check_hash=True)

model.load_state_dict(checkpoint['model'], strict=False)
# Out:
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['transformer.encoder.layers.0.self_attn.in_proj_weight', 'transformer.encoder.layers.0.self_attn.in_proj_bias', 'transformer.encoder.layers.1.self_attn.in_proj_weight', 'transformer.encoder.layers.1.self_attn.in_proj_bias', 'transformer.encoder.layers.2.self_attn.in_proj_weight', 'transformer.encoder.layers.2.self_attn.in_proj_bias', 'transformer.encoder.layers.3.self_attn.in_proj_weight', 'transformer.encoder.layers.3.self_attn.in_proj_bias', 'transformer.encoder.layers.4.self_attn.in_proj_weight', 'transformer.encoder.layers.4.self_attn.in_proj_bias', 'transformer.encoder.layers.5.self_attn.in_proj_weight', 'transformer.encoder.layers.5.self_attn.in_proj_bias', 'transformer.decoder.layers.0.self_attn.in_proj_weight', 'transformer.decoder.layers.0.self_attn.in_proj_bias', 'transformer.decoder.layers.0.multihead_attn.in_proj_weight', 'transformer.decoder.layers.0.multihead_attn.in_proj_bias', 'transformer.decoder.layers.1.self_attn.in_proj_weight', 'transformer.decoder.layers.1.self_attn.in_proj_bias', 'transformer.decoder.layers.1.multihead_attn.in_proj_weight', 'transformer.decoder.layers.1.multihead_attn.in_proj_bias', 'transformer.decoder.layers.2.self_attn.in_proj_weight', 'transformer.decoder.layers.2.self_attn.in_proj_bias', 'transformer.decoder.layers.2.multihead_attn.in_proj_weight', 'transformer.decoder.layers.2.multihead_attn.in_proj_bias', 'transformer.decoder.layers.3.self_attn.in_proj_weight', 'transformer.decoder.layers.3.self_attn.in_proj_bias', 'transformer.decoder.layers.3.multihead_attn.in_proj_weight', 'transformer.decoder.layers.3.multihead_attn.in_proj_bias', 'transformer.decoder.layers.4.self_attn.in_proj_weight', 'transformer.decoder.layers.4.self_attn.in_proj_bias', 'transformer.decoder.layers.4.multihead_attn.in_proj_weight', 'transformer.decoder.layers.4.multihead_attn.in_proj_bias', 'transformer.decoder.layers.5.self_attn.in_proj_weight', 'transformer.decoder.layers.5.self_attn.in_proj_bias', 'transformer.decoder.layers.5.multihead_attn.in_proj_weight', 'transformer.decoder.layers.5.multihead_attn.in_proj_bias'])

# %% [markdown]
# > DETR model

# %%
def evaluate(model, gen, im, device, image_id=None):
    
    # 평균-분산 정규화 (train dataset의 통계량을 (test) input image에 사용
    img=transform(im).unsqueeze(0).to(device)
    
    # model 통과
    outputs =model(img)
    
    # 정확도 70% 이상의 예측만 사용
    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1] # background 제외
    keep = probas.max(-1).values > 0.7
    
    if keep.nonzero().shape[0] <=1 : # detect된 object
        return
    
    #* 한 개는 evalute 할 필요가 없나요
    
    # 원래 cuda에 적재되어있던 좌표들
    outputs['pred_boxes'] = outputs['pred_boxes'].cpu()
    
    # [0,1]의 상대 좌표를 원래의 좌표로 복구
    bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)
    
    ##################
    ### attention weight 저장
    ##################
    
    conv_features, enc_attn_weights, dec_attn_weights = [], [], []
    test_weights=[]
    # model을 통과하면서 값을 저장
    # 이 때, output[0] : [token, 1, hidden_dim] --> 토큰
    # output[1] : [1, token, token] --> 가중치
    hooks = [
        # real bacbkone (backbone[-1] : positional embeddings)
        model.backbone[-2].register_forward_hook(
        lambda self, input, output: conv_features.append(output)
        ),
        
        # transformer encoder 내 마지막 layer의 self attention 층
        # model.transformer.encoder.layers[-1].self_attn.register_forward_hook(
        # lambda self, input, output: enc_attn_weights.append(output[1])
        #         ),
        
        # transformer decoder 내 마지막 layer의 multihead_attn 층
        model.transformer.decoder.layers[-1].multihead_attn.register_forward_hook(
        lambda self, input, output: dec_attn_weights.append(output[1])
        ),
        
        model.transformer.encoder.layers[-1].self_attn.register_forward_hook(
        lambda self, input, output: test_weights.append(output)
        )
    
    ]
        

    # transformer encoder 내 모든 layer의 output 저장
    # default : (enc_layer = 6)
    for layer in model.transformer.encoder.layers:
        hook=layer.self_attn.register_forward_hook(
        lambda self, input, output : enc_attn_weights.append(output[1])
        )
        hooks.append(hook)
                   ###
    ##################
    
    # 모델 통과(및 저장)
    model(img)
    
#     return enc_attn_weights
    # hook 제거
    for hook in hooks:
        hook.remove()
    
    # 리스트는 필요 없다.
    # 우선 위의 for문을 통해 encoder layer의 모든 가중치를 저장은 해놨으나,
    # 여기서는 encoder의 마지막 layer만을 사용하자.
    conv_features = conv_features[0] # feature-map
    enc_attn_weights = enc_attn_weights[-1] # 마지막 encoder layer의 가중치만 사용 (256개의 값)
    dec_attn_weights = dec_attn_weights[0] # 마지막 decoder layer의 가중치만 사용 (256개의 값)
    
    #  get the shape of feature map
    
    h, w = conv_features['0'].tensors.shape[-2:] # Nested tensor -> tensors
#     img_np = np.array(im).astype(np.float)
    
    fig, axs = plt.subplots(ncols=len(bboxes_scaled), nrows=2, figsize=(22,7))
    
    # object queries는 100차원(default)이기 때문에 그 중에 
    # 0.7(default) 이상의 신뢰도를 보이는 query만을 사용해야 한다. 
    for idx, ax_i, (xmin, ymin, xmax, ymax) in zip(keep.nonzero(), axs.T, bboxes_scaled):
        ax = ax_i[0]
        cam = gen.generate_ours(img, idx, use_lrp=False)
        cam = (cam - cam.min()) / (cam.max() - cam.min()) # 점수 정규화
        cmap = plt.cm.get_cmap('Blues').reversed()
        ax.imshow(cam.view(h, w).data.cpu().numpy(), cmap=cmap)
        ax.axis('off')
        ax.set_title(f'query id: {idx.item()}')
        ax = ax_i[1]
        ax.imshow(im)
        ax.add_patch(plt.Rectangle((xmin.detach(), ymin.detach()), 
                                  xmax.detach() - xmin.detach(),
                                   ymax.detach() - ymin.detach(), 
                                   fill=False, color='blue', linewidth=3))
        ax.axis('off')
        ax.set_title(CLASSES[probas[idx].argmax()])
    
    id_str = '' if image_id == None else image_id
    fig.tight_layout()
    plt.show

# %% [markdown]
# > Generator py파일 확인
#     > 그 중 method view 확인

# %%
def detect(im, model, confidence=0.7):
    img=transform(im).unsqueeze(0).to(device)

    outputs=model(img)
    
    assert img.shape[-2] <= 1600 and img.shape[-1] <= 1600

    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > confidence

    # 0과 1사이의 boxes 값을 image scale로 확대합니다.
    bboxes_scaled = rescale_bboxes(outputs['pred_boxes'].cpu()[0, keep], im.size)
    scores, boxes=probas[keep], bboxes_scaled
    
    return scores, boxes

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
im = Image.open(requests.get(url, stream=True).raw)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F216606EDD0>

# %%
def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), COLORS * 100):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{CLASSES[cl]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
scores, boxes=detect(im, model)
plot_results(im, scores, boxes)

# %%
gen= Generator(model)

# %%
evaluate(model, gen, im, 'cuda')
# Out:
# /home/jrkim/.conda/envs/jsp_xod/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   del sys.path[0]

# %% [markdown]
# ## Another example

# %%
url='https://post-phinf.pstatic.net/MjAyMTA0MTNfMjk2/MDAxNjE4MjcyMjM3MDE0.1s9vYMkb36aeBv069zZo6QJDcuwOd1_tggAvMI6TJGUg.gpjghNMhYrw-TEkDmgjuZX-Kq_3pF-_wyP_5zgUNxUgg.JPEG/img_20210412162634_517287nv.jpg?type=w1200'
im = Image.open(requests.get(url, stream=True).raw)

# %%
scores, boxes=detect(im, model)

# %%
plot_results(im, scores, boxes)

# %%
evaluate(model, gen, im, 'cuda')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10940/3629850716.py in <module>
# ----> 1 evaluate(model, gen, im, 'cuda')
#
# NameError: name 'gen' is not defined

# %%
url='https://t1.daumcdn.net/liveboard/KCCAUTO/a508e566d18b4eb3b502c16c3068d6f1.JPG'
im=Image.open(requests.get(url, stream=True).raw)

# %%
scores, boxes=detect(im, model)
plot_results(im, scores, boxes)

# %%
evaluate(model, gen, im, 'cuda')

# %%
url = 'http://images.cocodataset.org/val2017/000000192191.jpg'
im = Image.open(requests.get(url, stream=True).raw)

evaluate(model, gen, im, 'cuda')

# %%
url = 'http://images.cocodataset.org/val2017/000000192191.jpg'
im = Image.open(requests.get(url, stream=True).raw)

# %%
scores, boxes=detect(im, model)
plot_results(im, scores, boxes)

# %%
evaluate(model, gen, im, 'cuda')

# %% [markdown]
# ## Attention-map

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
im = Image.open(requests.get(url, stream=True).raw)

# %%
# 정규화 + 사이즈 변경 + 텐서 전환
img = transform(im).unsqueeze(0)

# %% [markdown]
# ### Model in GAE

# %%
device='cuda'
args = Namespace(aux_loss=True, backbone='resnet50', batch_size=1, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, coco_path=None, dataset_file='coco', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=300, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=100, num_workers=2, output_dir='', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)

model, criterion, postprocessors = build_model(args)
model.to(device)

checkpoint=torch.hub.load_state_dict_from_url(
args.resume, map_location='cpu', check_hash=True)

model.load_state_dict(checkpoint['model'], strict=False)
# Out:
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['transformer.encoder.layers.0.self_attn.in_proj_weight', 'transformer.encoder.layers.0.self_attn.in_proj_bias', 'transformer.encoder.layers.1.self_attn.in_proj_weight', 'transformer.encoder.layers.1.self_attn.in_proj_bias', 'transformer.encoder.layers.2.self_attn.in_proj_weight', 'transformer.encoder.layers.2.self_attn.in_proj_bias', 'transformer.encoder.layers.3.self_attn.in_proj_weight', 'transformer.encoder.layers.3.self_attn.in_proj_bias', 'transformer.encoder.layers.4.self_attn.in_proj_weight', 'transformer.encoder.layers.4.self_attn.in_proj_bias', 'transformer.encoder.layers.5.self_attn.in_proj_weight', 'transformer.encoder.layers.5.self_attn.in_proj_bias', 'transformer.decoder.layers.0.self_attn.in_proj_weight', 'transformer.decoder.layers.0.self_attn.in_proj_bias', 'transformer.decoder.layers.0.multihead_attn.in_proj_weight', 'transformer.decoder.layers.0.multihead_attn.in_proj_bias', 'transformer.decoder.layers.1.self_attn.in_proj_weight', 'transformer.decoder.layers.1.self_attn.in_proj_bias', 'transformer.decoder.layers.1.multihead_attn.in_proj_weight', 'transformer.decoder.layers.1.multihead_attn.in_proj_bias', 'transformer.decoder.layers.2.self_attn.in_proj_weight', 'transformer.decoder.layers.2.self_attn.in_proj_bias', 'transformer.decoder.layers.2.multihead_attn.in_proj_weight', 'transformer.decoder.layers.2.multihead_attn.in_proj_bias', 'transformer.decoder.layers.3.self_attn.in_proj_weight', 'transformer.decoder.layers.3.self_attn.in_proj_bias', 'transformer.decoder.layers.3.multihead_attn.in_proj_weight', 'transformer.decoder.layers.3.multihead_attn.in_proj_bias', 'transformer.decoder.layers.4.self_attn.in_proj_weight', 'transformer.decoder.layers.4.self_attn.in_proj_bias', 'transformer.decoder.layers.4.multihead_attn.in_proj_weight', 'transformer.decoder.layers.4.multihead_attn.in_proj_bias', 'transformer.decoder.layers.5.self_attn.in_proj_weight', 'transformer.decoder.layers.5.self_attn.in_proj_bias', 'transformer.decoder.layers.5.multihead_attn.in_proj_weight', 'transformer.decoder.layers.5.multihead_attn.in_proj_bias'])

# %%
# up-values를 통해 output을 저장하는 리스트
conv_features, enc_attn_weights, dec_attn_weights = [], [], []

# 모델을 통과시킬 때 값을 저장할 수 있게끔.
hooks = [
    model.backbone[-2].register_forward_hook(
        lambda self, input, output: conv_features.append(output)
    ),
    model.transformer.encoder.layers[-1].self_attn.register_forward_hook( 
        lambda self, input, output: enc_attn_weights.append(output) # encoder : 여섯 개의 layer 중 last lyaer
    ),
    model.transformer.decoder.layers[-1].multihead_attn.register_forward_hook(
        lambda self, input, output: dec_attn_weights.append(output) # decoder : 여섯 개의 layer 중 last layer
    ),
]

# %%
# 모델 통과
outputs = model(img.to(device))

# 0.9 이상의 정확도를 보이는 bounding box만 남긴다.
probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
keep = probas.max(-1).values > 0.9

# convert boxes from [0; 1] to image scales
bboxes_scaled = rescale_bboxes(outputs['pred_boxes'].cpu()[0, keep], im.size)

for hook in hooks:
    hook.remove()

# %%
enc_attn_weights[0].shape
# Out:
# torch.Size([850, 1, 256])

# %% [markdown]
# ### Other model

# %%
model = torch.hub.load('facebookresearch/detr', 'detr_resnet50', pretrained=True)
model.eval();
# Out:
# Using cache found in /home/jrkim/.cache/torch/hub/facebookresearch_detr_master

# %%
# up-values를 통해 output을 저장하는 리스트
conv_features, enc_attn_weights, dec_attn_weights = [], [], []

# 모델을 통과시킬 때 값을 저장할 수 있게끔.
hooks = [
    model.backbone[-2].register_forward_hook(
        lambda self, input, output: conv_features.append(output)
    ),
    model.transformer.encoder.layers[-1].self_attn.register_forward_hook( 
        lambda self, input, output: enc_attn_weights.append(output) # encoder : 여섯 개의 layer 중 last lyaer
    ),
    model.transformer.decoder.layers[-1].multihead_attn.register_forward_hook(
        lambda self, input, output: dec_attn_weights.append(output) # decoder : 여섯 개의 layer 중 last layer
    ),
]

# %%
# 모델 통과
outputs = model(img)

# 0.9 이상의 정확도를 보이는 bounding box만 남긴다.
probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
keep = probas.max(-1).values > 0.9

# convert boxes from [0; 1] to image scales
bboxes_scaled = rescale_bboxes(outputs['pred_boxes'].cpu()[0, keep], im.size)

for hook in hooks:
    hook.remove()

# %%
enc_attn_weights[0][0].shape
# Out:
# torch.Size([850, 1, 256])

# %%
enc_attn_weights[0][1].shape
# Out:
# torch.Size([1, 850, 850])

# %%
enc_attn_weights[0][0].shape
# Out:
# torch.Size([850, 1, 256])

# %% [markdown]
# > 즉,모델의 차이로 **attention weights**를 저장하는 방식이 다르다. (위의 방식으로 model을 불러왔을 때에는 Transformer encoder에서 output 자체가 (값, 가중치)의 tuple로 들어와 output[1]을 이용해야 attention map을 받을 수 있다.
#  다만, 현재 jupyter noteobook에서의 model은 위처럼 tuple로 받지 않는 것처럼 보인다..

# %% [markdown]
# > 결론적으로, 이 model에서는 attention map weights를 받지 않아도 된다는 것인데, 아마도 어디에선가 착오가 생긴듯 하다. 위의 evaluation에서 output[1]을 받게되면 원래 [wh, wh] 차원의 attention weights를 얻어야 하는데, 사실상 output[0][1]의 역할을 하기 때문에 wh길이 token의 2번째(index로 1)의 값을 그대로 얻어버리는, [256] 차원의 token 값만을 얻게 되는 것.

# %% [markdown]
# > 다만, 위의 evaluate 함수에서 enc_attn_weights 등을 저장은 하지만 Explanation Generator에서는 사용하지 않는 것으로 보인다
# 이에 대해선 아래의 Module ExplanationGenerator를 참고하자..

# %% [markdown]
# ## Explanation Generator

# %%
import numpy as np
import torch
from torch.nn.functional import softmax

# %%
gen=Generator(model)

# %%
img = transform(im)

# %% [markdown]
# > 본 모델은
# - DETR과 비교하여 Transformer 모델 자체를 상당부분 수정하였습니다. (DETR/models/transformer).
# - Transformer 내 MultiheadAttention을 상당부분 수정하였습니다.(DETR/modules/layers). 즉, self_attn이 달라집니다.

# %% [markdown]
# > 아래에서 말하는 cam은 **final attention map $\bar{A}$**를 뜻합니다.
# (혹은 그 식을 도출하는 과정에서의 attention map)
# (Cam은 보통 Class Activation map 이기 때문)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 식 (5)
def avg_heads(cam, grad):
    cam = cam.reshape(-1, cam.shape[-2], cam.shape[-1])
    grad = grad.reshape(-1, grad.shape[-2], grad.shape[-1])
    cam = grad * cam
    cam = cam.clamp(min=0).mean(dim=0)
    return cam

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 식 (6), (7)
# 증가분을 반환합니다(위 식의 뒤쪽 항)
def apply_self_attention_rules(R_ss, R_sq, cam_ss):
    R_sq_addition = torch.matmul(cam_ss, R_sq)
    R_ss_addition = torch.matmul(cam_ss, R_ss)
    return R_ss_addition, R_sq_addition

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 식 (10)
# bi-modal에 대한 aggregation rule
def apply_mm_attention_rules(R_ss, R_qq, cam_sq, apply_normalization=True,
                            apply_self_in_rule_10=True):
    R_ss_normalized = R_ss
    R_qq_normalized = R_qq
    
    if apply_normalization:
        R_ss_normalized = handle_residual(R_ss)
        R_qq_normalized = handle_residual(R_qq)
    R_sq_addition = torch.matmul(R_ss_normalized.t(), torch.matmul(cam_sq, R_qq_normalized))
    if not apply_self_in_rule_10:
        R_sq_addition = cam_sq
    R_sq_addition[torch.isnan(R_sq_addition)] = 0
    return R_sq_addition

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 위 식(10)에 쓰이는 Normalization (식(8),(9))

def handle_residual(orig_self_attention):
    self_attention = orig_self_attention.clone()
    diag_idx = range(self_attention.shape[-1])
    self_attention -= torch.eye(self_attention.shape[-1]).to(self_attention.device)
    assert self_attention[diag_idx, diag_idx].min() >= 0
    self_attention = self_attention / self_attention.sum(dim=-1, keepdim=True)
    self_attention += torch.eye(self_attention.shape[-1]).to(self_attention.device)
    return self_attention

# %%
class Generator:
    def __init__(self, model):
        self.model = model
        self.model.eval() # evaluate 시 dropout, batchnorm 등은 사용하지 않는다.
        
    
    def forward(self, input_ids, attention_mask):
        return self.model(input_ids, attention_mask) #*
    
    def generate_transformer_attn(self, img, target_index, index=None):
        outputs = self.model(img)
        
        kwargs = {"alpha": 1,
                  "target_index": target_index}
                
        if index == None:
            index = outputs['pred_logits'][0, target_index, :-1].max(1)[1] #* max(0)까지만 될텐데?
        
        kwargs["target_class"] = index
        
        one_hot = torch.zeros_like(outputs['pred_logits']).to(outputs['pred_logits'].device)
        one_hot[0, target_index, index] = 1 # [1, 100, 92] 차원으로 된 원핫벡터
        one_hot_vector = one_hot.clone().detach() # 복사하는 방법. 
        one_hot.requires_grad_(True) # 복사 후 원본은 다시 autograd가 추적해야 한다.
        one_hot = torch.sum(one_hot.cuda() * outputs['pred_logits'])
        
        self.model_zero_grad() # 모델 내 gradient 0으로 초기화
        one_hot.backward(retain_graph=True) # backward를 하는 동안에 중간 가중치들은 보존한다.
        
        self.model.relprop(one_hot_vector, **kwargs) # 타당성전파(Relevance propagation)
        
        decoder_blocks = self.model.transformer.decoder.layers
        encoder_blocks = self.model.transformer.encoder.layers
        
        # 타당성 행렬(Relevancy matrices) 초기화
        image_bboxes = encoder_blocks[0].self_attn.get_attn().shape[-1] # wh (8, 850, 850)
        queries_num = decoder_blocks[0].self_attn.get_attn().shape[-1] # 100 (8,100,100)
    
        
        # image self attention matrix - (wh x wh) 크기의 Identity 행렬
        self.R_i_i = torch.eye(image_bboxes,# 
                               image_bboxes).to(encoder_blocks[0].self_attn.get_attn().device)
        
        # queries self attention matrix
        self.R_q_q = torch.eye(queries_num,
                               queries_num).to(encoder_blocks[0].self_attn.get_attn().device)
        
        # image --> queries의 영향 ( (100 x wh) 크기 행렬)
        self.R.q_i = torch.zeros(queries_num,
                                image_bboxes).to(encoder_blocks[0].self_attn.get_attn().device)
        
        # 마지막 layer에서 생성한 R_q_i (논문 내 수식 (5))
        decoder_last = decoder_blocks[-1]
        cam_q_i = decoder_last.multihead_attn.get_attn_cam().detach()
        grad_q_i = decoder_last.multihead_attn.get_attn_gradients().detach()
        cam_q_i = avg_heads(cam_q_i, grad_q_i) # heads 차원(default : 8)을 따른 평균
        self.R_q_i = cam_q_i
        aggregated = self.R_q_i.unsqueeze_(0)
        
        aggregated = aggregated[:, target_index, :].unsqueeze(0) #* 차원 : 
        
        return aggregated
    
    
    def generate_ours(self, img, target_index, index=None, use_lrp=True,
                     normalize_self_attention=True, apply_self_in_rule_10=True):
        self.use_lrp = use_lrp
        self.normalize_self_attention = normalize_self_attention
        self.apply_self_in_rule_10 = apply_self_in_rule_10
        
        
        ########## 위와 85% 동일
        outputs = self.model(img)
        outputs = outputs['pred_logits']
        kwargs = {"alpha": 1, 
                 "target_index": target_index}
        
        if index == None:
            index = outputs[0, target_index, :-1].max(1)[1]
        
        kwargs["target_class"] = index
        
        one_hot = torch.zeros_like(outputs).to(outputs,device)
        one_hot[0, target_index, index] = 1
        one_hot_vector = one_hot # 이건 그냥 주소 복사 아닌가. .clone().detach()해야할 듯
        one_hot.require_grad_(True) # 그래디언트 추적
        one_hot = torch.sum(one_hot.cuda() * outputs)
        
        self.model.zero_grad() # 모델 내 그래디언트를 0으로 초기화
        one_hot.backward(retain_graph=True) # 중간의 가중치들은 보존
        
        if use_lrp:
            self.model.relprop(one_hot_vector, **kwargs)
            
        decoder_blocks = self.model.transformer.decoder.layers
        encoder_blocks = self.model.transformer.encoder.layers


        image_bboxes = encoder_blocks[0].self_attn.get_attn().shape[-1]
        queries_num = decoder_blocks[0].self_attn.get_attn().shape[-1]

        self.R_i_i = torch.eye(image_bboxes, image_bboxes).to(encoder_blocks[0].self_attn.get_attn().device)

        self.R_q_q = torch.eye(queries_num, queries_num).to(encoder_blocks[0].self_attn.get_attn().device)

        self.R_q_i = torch.zeros(queries_num, image_bboxes).to(encoder_blocks[0].self_attn.get_attn().device)

        
        ####################
         # encoder 내에서 image에 대한 self-attention
        self.handle_self_attention_image(encoder_blocks)

        # decoder 내에서 queries에 대한 self-attention + Multi-modal attention
        for blk in decoder_blocks:
            # decoder self attention
            self.handle_co_attn_self_query(blk)

            # encoder decoder attention
            self.handle_co_attn_query(blk)
            
        aggregated = self.R_q_i.unsqueeze_(0)

        aggregated = aggregated[:,target_index, :].unsqueeze_(0).detach()
        return aggregated

# %% [markdown]
# > 웬만하면 추가 학습을 시키지 않는 post-hoc method를 구성하고 싶다.
# > Feature map : Backbone
# > Attention map : Transformer
#
#
# > 당장할 것
# 1. Relprop 함수
# 1.1. handle 함수들
# 2. 기타 베이스라인 코드 분석(raw_attn, rollout, ... )
# 3. 특정한 object를 중심으로 전파가 어떤식으로 진행되는지.
#
# > 추가적으로 할만한 것
# 1. Backbone Model을 바꿨을 경우 attention map, Relevancy map, Final output 등 변화 분석(Pretrained)
# 2. Backbone까지 Gradient를 주었을 때(현재 Feature map까지만 전파한다.)
# 3. Transformer Input인 Feature map 시각화 or 분석
#
# >$\alpha$. Input에 noise를 줄 경우 feature map , attention map, Relevance map에 대한 변화
# $\beta$.  Gradient ascent 에 대한 " 변화
#
# ----
#
# > 잘 안 될 경우 특정한 Loss를 도입해서 학습시키기.

# %%
def handle_self_attention_image(self, blocks):
        for blk in blocks:
            grad = blk.self_attn.get_attn_gradients().detach()
            if self.use_lrp:
                cam = blk.self_attn.get_attn_cam().detach()
            else:
                cam = blk.self_attn.get_attn().detach()
            cam = avg_heads(cam, grad)
            self.R_i_i += torch.matmul(cam, self.R_i_i)

    def handle_co_attn_self_query(self, block):
        grad = block.self_attn.get_attn_gradients().detach()
        if self.use_lrp:
            cam = block.self_attn.get_attn_cam().detach()
        else:
            cam = block.self_attn.get_attn().detach()
        cam = avg_heads(cam, grad)
        R_q_q_add, R_q_i_add = apply_self_attention_rules(self.R_q_q, self.R_q_i, cam)
        self.R_q_q += R_q_q_add
        self.R_q_i += R_q_i_add

    def handle_co_attn_query(self, block):
        if self.use_lrp:
            cam_q_i = block.multihead_attn.get_attn_cam().detach()
        else:
            cam_q_i = block.multihead_attn.get_attn().detach()
        grad_q_i = block.multihead_attn.get_attn_gradients().detach()
        cam_q_i = avg_heads(cam_q_i, grad_q_i)
        self.R_q_i += apply_mm_attention_rules(self.R_q_q, self.R_i_i, cam_q_i,
                                               apply_normalization=self.normalize_self_attention,
                                               apply_self_in_rule_10=self.apply_self_in_rule_10)

# %% [markdown]
# ## Implementation of GAE

# %%
device='cuda'
args = Namespace(aux_loss=True, backbone='resnet50', batch_size=1, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, coco_path=None, dataset_file='coco', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=300, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=100, num_workers=2, output_dir='', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)

model, criterion, postprocessors = build_model(args)
model.to(device)

checkpoint=torch.hub.load_state_dict_from_url(
args.resume, map_location='cpu', check_hash=True)

model.load_state_dict(checkpoint['model'], strict=False)
# Out:
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['transformer.encoder.layers.0.self_attn.in_proj_weight', 'transformer.encoder.layers.0.self_attn.in_proj_bias', 'transformer.encoder.layers.1.self_attn.in_proj_weight', 'transformer.encoder.layers.1.self_attn.in_proj_bias', 'transformer.encoder.layers.2.self_attn.in_proj_weight', 'transformer.encoder.layers.2.self_attn.in_proj_bias', 'transformer.encoder.layers.3.self_attn.in_proj_weight', 'transformer.encoder.layers.3.self_attn.in_proj_bias', 'transformer.encoder.layers.4.self_attn.in_proj_weight', 'transformer.encoder.layers.4.self_attn.in_proj_bias', 'transformer.encoder.layers.5.self_attn.in_proj_weight', 'transformer.encoder.layers.5.self_attn.in_proj_bias', 'transformer.decoder.layers.0.self_attn.in_proj_weight', 'transformer.decoder.layers.0.self_attn.in_proj_bias', 'transformer.decoder.layers.0.multihead_attn.in_proj_weight', 'transformer.decoder.layers.0.multihead_attn.in_proj_bias', 'transformer.decoder.layers.1.self_attn.in_proj_weight', 'transformer.decoder.layers.1.self_attn.in_proj_bias', 'transformer.decoder.layers.1.multihead_attn.in_proj_weight', 'transformer.decoder.layers.1.multihead_attn.in_proj_bias', 'transformer.decoder.layers.2.self_attn.in_proj_weight', 'transformer.decoder.layers.2.self_attn.in_proj_bias', 'transformer.decoder.layers.2.multihead_attn.in_proj_weight', 'transformer.decoder.layers.2.multihead_attn.in_proj_bias', 'transformer.decoder.layers.3.self_attn.in_proj_weight', 'transformer.decoder.layers.3.self_attn.in_proj_bias', 'transformer.decoder.layers.3.multihead_attn.in_proj_weight', 'transformer.decoder.layers.3.multihead_attn.in_proj_bias', 'transformer.decoder.layers.4.self_attn.in_proj_weight', 'transformer.decoder.layers.4.self_attn.in_proj_bias', 'transformer.decoder.layers.4.multihead_attn.in_proj_weight', 'transformer.decoder.layers.4.multihead_attn.in_proj_bias', 'transformer.decoder.layers.5.self_attn.in_proj_weight', 'transformer.decoder.layers.5.self_attn.in_proj_bias', 'transformer.decoder.layers.5.multihead_attn.in_proj_weight', 'transformer.decoder.layers.5.multihead_attn.in_proj_bias'])

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
im = Image.open(requests.get(url, stream=True).raw)

# %%
# 평균-분산 정규화 (train dataset의 통계량을 (test) input image에 사용
img=transform(im).unsqueeze(0).to(device)

# model 통과
outputs =model(img)

# 정확도 70% 이상의 예측만 사용
probas = outputs['pred_logits'].softmax(-1)[0, :, :-1] # background 제외
keep = probas.max(-1).values > 0.7

if keep.nonzero().shape[0] <=1 : # detect된 object
    raise Nameerror('no')

#* 한 개는 evalute 할 필요가 없나요

# 원래 cuda에 적재되어있던 좌표들
outputs['pred_boxes'] = outputs['pred_boxes'].cpu()

# [0,1]의 상대 좌표를 원래의 좌표로 복구
bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)

# %%
# attention weight 저장


conv_features, enc_attn_weights, dec_attn_weights = [], [], []

hooks = [
    # real bacbkone (backbone[-1] : positional embeddings)
    model.backbone[-2].register_forward_hook(
    lambda self, input, output: conv_features.append(output)
    ),

    # transformer encoder 내 마지막 layer의 self attention 층
    # model.transformer.encoder.layers[-1].self_attn.register_forward_hook(
    # lambda self, input, output: enc_attn_weights.append(output[1])
    #         ),

    # transformer decoder 내 마지막 layer의 multihead_attn 층
    model.transformer.decoder.layers[-1].multihead_attn.register_forward_hook(
    lambda self, input, output: dec_attn_weights.append(output[1])
    ),

]

# %%
# transformer encoder 내 모든 layer의 output 저장
for layer in model.transformer.encoder.layers:
    hook=layer.self_attn.register_forward_hook(
    lambda self, input, output : enc_attn_weights.append(output[1])
    )
    hooks.append(hook)

# %%
# 모델 통과
model(img)

# hook 제거
for hook in hooks:
    hook.remove()
# Out:
# {'pred_logits': tensor([[[-19.4904,   0.3612,  -9.8977,  ...,  -9.0719, -11.6607,  10.0762],
#           [-16.9662,  -0.9013, -11.4362,  ...,  -6.5859,  -3.3790,  10.0062],
#           [-20.3989,   0.0927, -10.7189,  ...,  -7.7549,  -9.5425,  10.4645],
#           ...,
#           [-19.2905,  -1.2699, -10.4990,  ...,  -8.6584, -12.4653,  10.7449],
#           [-12.3076,   2.1335,  -4.4207,  ...,  -6.4379,  -7.6589,   5.9967],
#           [-18.9981,   0.4589, -10.8925,  ...,  -9.3183, -11.3919,  10.3736]]],
#         device='cuda:0', grad_fn=<SqueezeBackward1>),
#  'pred_boxes': tensor([[[0.4948, 0.5482, 0.9913, 0.8806],
#           [0.5447, 0.2768, 0.0796, 0.2485],
#           [0.4320, 0.6185, 0.8540, 0.7418],
#           [0.5520, 0.1806, 0.0402, 0.0617],
#           [0.4996, 0.4149, 0.9998, 0.8246],
#           [0.4999, 0.5228, 0.9998, 0.9301],
#           [0.5417, 0.2676, 0.0403, 0.2053],
#           [0.1553, 0.2365, 0.2307, 0.1804],
#           [0.1794, 0.1838, 0.1748, 0.0623],
#           [0.4998, 0.3478, 0.9989, 0.6929],
#           [0.5388, 0.5143, 0.9092, 0.9510],
#           [0.4997, 0.5528, 1.0000, 0.8721],
#           [0.7719, 0.5020, 0.4553, 0.8884],
#           [0.8766, 0.6125, 0.2439, 0.7325],
#           [0.2925, 0.5948, 0.5626, 0.7886],
#           [0.1615, 0.1859, 0.2267, 0.1103],
#           [0.0441, 0.0969, 0.0890, 0.1477],
#           [0.8128, 0.1302, 0.3700, 0.2567],
#           [0.8798, 0.5769, 0.2366, 0.7059],
#           [0.4997, 0.4269, 0.9994, 0.8422],
#           [0.5004, 0.5430, 0.9866, 0.8867],
#           [0.4999, 0.6229, 1.0000, 0.7301],
#           [0.1690, 0.1845, 0.3033, 0.1421],
#           [0.1086, 0.1900, 0.1822, 0.0952],
#           [0.8867, 0.5900, 0.2237, 0.7233],
#           [0.5057, 0.3458, 0.1324, 0.3974],
#           [0.4998, 0.5354, 1.0000, 0.8960],
#           [0.4997, 0.4060, 0.9997, 0.8099],
#           [0.1682, 0.1870, 0.2157, 0.0875],
#           [0.5148, 0.6090, 0.9557, 0.7571],
#           [0.5964, 0.5024, 0.8079, 0.9720],
#           [0.6102, 0.4838, 0.7797, 0.9130],
#           [0.4998, 0.6048, 0.9997, 0.7655],
#           [0.5350, 0.3692, 0.0761, 0.4571],
#           [0.5485, 0.3380, 0.0750, 0.3971],
#           [0.7671, 0.4812, 0.4659, 0.8616],
#           [0.5926, 0.5151, 0.8092, 0.9373],
#           [0.5536, 0.2390, 0.0484, 0.1625],
#           [0.5518, 0.2886, 0.0563, 0.2642],
#           [0.5270, 0.5167, 0.9268, 0.9361],
#           [0.1645, 0.1886, 0.2084, 0.0860],
#           [0.4996, 0.3732, 1.0000, 0.7459],
#           [0.7699, 0.4092, 0.4629, 0.7155],
#           [0.6523, 0.4913, 0.7005, 0.9615]]], device='cuda:0',
#         grad_fn=<SelectBackward>),
#  'aux_outputs': [{'pred_logits': tensor([[[-16.4994,  -1.5937,  -6.7978,  ..., -10.0949,  -6.1318,   7.1786],
#             [-16.6063,  -2.4193, -11.9099,  ...,  -5.4068,  -0.9253,   9.1652],
#             [-16.7139,  -0.4324,  -5.1485,  ...,  -7.9793,  -9.0683,   7.5305],
#             ...,
#             [-18.6117,   0.3701,  -6.0016,  ...,  -9.1361,  -9.2006,   8.2839],
#             [-10.8104,   4.3379,  -3.5243,  ...,  -5.8101,  -6.1811,   4.6066],
#             [-17.4710,  -1.4975,  -9.4466,  ...,  -7.6881,  -3.4168,   7.7277]]],
#           device='cuda:0', grad_fn=<UnbindBackward>),
#    'pred_boxes': tensor([[[0.4971, 0.5695, 0.9959, 0.8168],
#             [0.5523, 0.2607, 0.0542, 0.2141],
#             [0.4872, 0.6086, 0.9994, 0.7651],
#             [0.5567, 0.2594, 0.0976, 0.1581],
#             [0.4925, 0.2992, 0.9290, 0.5639],
#             [0.4236, 0.3270, 0.3420, 0.3907],
#             [0.5393, 0.2573, 0.0634, 0.1765],
#             [0.1772, 0.1909, 0.2062, 0.0888],
#             [0.1756, 0.1831, 0.1990, 0.1041],
#             [0.4998, 0.3338, 1.0000, 0.6801],
#             [0.7408, 0.4994, 0.5097, 0.9122],
#             [0.4822, 0.5953, 0.9607, 0.7798],
#             [0.7729, 0.4158, 0.4514, 0.7111],
#             [0.8630, 0.6133, 0.2660, 0.6822],
#             [0.3356, 0.4804, 0.5387, 0.7709],
#             [0.1654, 0.1346, 0.2562, 0.2233],
#             [0.1665, 0.1836, 0.1897, 0.0927],
#             [0.6347, 0.1150, 0.6841, 0.2201],
#             [0.8382, 0.5899, 0.3102, 0.6963],
#             [0.4999, 0.4278, 0.9994, 0.8610],
#             [0.4981, 0.6154, 0.9988, 0.7400],
#             [0.1833, 0.1643, 0.2373, 0.0689],
#             [0.2563, 0.1954, 0.4127, 0.1457],
#             [0.8309, 0.5851, 0.3269, 0.7303],
#             [0.5465, 0.2708, 0.0556, 0.1961],
#             [0.4995, 0.5142, 1.0000, 0.9289],
#             [0.4999, 0.2808, 1.0000, 0.5585],
#             [0.1717, 0.1920, 0.2074, 0.0895],
#             [0.4998, 0.7158, 0.9826, 0.5637],
#             [0.5681, 0.5047, 0.8314, 0.9222],
#             [0.6878, 0.3658, 0.6103, 0.7230],
#             [0.4999, 0.5912, 0.9998, 0.8005],
#             [0.5556, 0.2743, 0.0542, 0.2216],
#             [0.5487, 0.2707, 0.0702, 0.2539],
#             [0.7690, 0.3999, 0.4539, 0.7820],
#             [0.7605, 0.4305, 0.4763, 0.8055],
#             [0.5504, 0.2752, 0.0614, 0.2292],
#             [0.5461, 0.2814, 0.0582, 0.1691],
#             [0.6501, 0.6038, 0.6783, 0.7833],
#             [0.1659, 0.1855, 0.2062, 0.0954],
#             [0.4988, 0.5228, 0.9999, 0.9311],
#             [0.7697, 0.4009, 0.4602, 0.7170],
#             [0.5695, 0.2474, 0.2025, 0.2875]]], device='cuda:0',
#           grad_fn=<UnbindBackward>)},
#   {'pred_logits': tensor([[[-18.0702,   0.6513,  -8.4444,  ...,  -9.4415,  -8.7748,   7.9649],
#             [-16.3504,  -1.0345,  -9.7205,  ...,  -6.4242,  -1.4828,   8.6174],
#             [-18.4212,  -0.1770,  -7.1413,  ...,  -7.5763, -10.8556,   8.7073],
#             ...,
#             [-19.6225,   2.0829,  -6.5548,  ...,  -9.4864, -13.8303,   9.4852],
#             [-11.4318,   2.5836,  -3.8162,  ...,  -7.3138,  -7.3818,   4.7435],
#             [-17.3887,  -1.2579,  -8.2871,  ...,  -7.2706,  -6.1323,   7.8053]]],
#           device='cuda:0', grad_fn=<UnbindBackward>),
#    'pred_boxes': tensor([[[0.4981, 0.5189, 1.0000, 0.9119],
#             [0.5519, 0.2836, 0.0977, 0.2487],
#             [0.4242, 0.6161, 0.8226, 0.7412],
#             [0.5518, 0.2501, 0.0481, 0.1483],
#             [0.5001, 0.5065, 1.0000, 0.9558],
#             [0.3939, 0.4660, 0.6931, 0.6863],
#             [0.5436, 0.2712, 0.0444, 0.2066],
#             [0.2252, 0.2527, 0.3666, 0.2204],
#             [0.1763, 0.1953, 0.2015, 0.0889],
#             [0.4998, 0.3610, 0.9990, 0.7238],
#             [0.6070, 0.5074, 0.7859, 0.9598],
#             [0.4999, 0.5672, 1.0000, 0.8406],
#             [0.7685, 0.4148, 0.4555, 0.7702],
#             [0.8767, 0.6139, 0.2458, 0.7352],
#             [0.3355, 0.5825, 0.5296, 0.7779],
#             [0.1950, 0.1601, 0.2857, 0.2133],
#             [0.1810, 0.1814, 0.2489, 0.1035],
#             [0.7522, 0.1549, 0.4728, 0.4021],
#             [0.8770, 0.5897, 0.2439, 0.7947],
#             [0.4997, 0.4242, 1.0000, 0.8476],
#             [0.4998, 0.6062, 1.0000, 0.7667],
#             [0.1970, 0.2047, 0.2065, 0.1015],
#             [0.1681, 0.2021, 0.2486, 0.1397],
#             [0.8716, 0.5959, 0.2491, 0.7123],
#             [0.5437, 0.2897, 0.0677, 0.2752],
#             [0.4996, 0.5211, 1.0000, 0.9188],
#             [0.4995, 0.3677, 1.0000, 0.7247],
#             [0.1731, 0.1939, 0.2178, 0.1004],
#             [0.5004, 0.6580, 0.9998, 0.6603],
#             [0.5101, 0.5412, 0.9558, 0.8726],
#             [0.5189, 0.4603, 0.9031, 0.8735],
#             [0.4998, 0.6031, 1.0000, 0.7750],
#             [0.5502, 0.3027, 0.0631, 0.2862],
#             [0.5473, 0.2702, 0.0605, 0.2467],
#             [0.7568, 0.4087, 0.4807, 0.7991],
#             [0.5015, 0.5005, 0.9986, 0.9358],
#             [0.5494, 0.2683, 0.0567, 0.2384],
#             [0.5500, 0.2867, 0.0656, 0.2517],
#             [0.6004, 0.5710, 0.7954, 0.8336],
#             [0.1803, 0.1896, 0.2190, 0.0968],
#             [0.4995, 0.4999, 1.0000, 0.9615],
#             [0.7726, 0.4074, 0.4579, 0.7128],
#             [0.5213, 0.3659, 0.8206, 0.6118]]], device='cuda:0',
#           grad_fn=<UnbindBackward>)},
#   {'pred_logits': tensor([[[-18.4103,  -0.1630,  -8.5374,  ...,  -8.3172,  -8.8280,   8.3683],
#             [-15.8666,  -1.4880, -11.4083,  ...,  -5.2373,  -0.7875,   9.0111],
#             [-19.5820,  -0.7077,  -7.3626,  ...,  -8.5802, -10.0976,   9.1237],
#             ...,
#             [-18.7655,  -0.0274,  -7.2882,  ...,  -8.0447, -11.4254,   9.3147],
#             [-12.1411,   2.6847,  -4.8780,  ...,  -6.3727,  -6.0946,   5.4079],
#             [-16.4132,  -1.3927,  -8.8189,  ...,  -6.9102,  -7.4673,   8.3628]]],
#           device='cuda:0', grad_fn=<UnbindBackward>),
#    'pred_boxes': tensor([[[0.4941, 0.5479, 0.9940, 0.8906],
#             [0.5363, 0.2811, 0.0865, 0.2558],
#             [0.3911, 0.6210, 0.7829, 0.7435],
#             [0.5534, 0.2249, 0.0426, 0.0989],
#             [0.4995, 0.4320, 1.0000, 0.8879],
#             [0.4641, 0.5121, 0.8554, 0.8678],
#             [0.5416, 0.2689, 0.0447, 0.2040],
#             [0.1568, 0.2452, 0.2400, 0.2089],
#             [0.1795, 0.1883, 0.1945, 0.0716],
#             [0.4999, 0.1830, 1.0000, 0.3656],
#             [0.5435, 0.5029, 0.9054, 0.9653],
#             [0.4997, 0.5699, 1.0000, 0.8297],
#             [0.7697, 0.4314, 0.4548, 0.7649],
#             [0.8600, 0.6155, 0.2804, 0.7412],
#             [0.3423, 0.5838, 0.4552, 0.7515],
#             [0.1722, 0.1964, 0.2478, 0.1972],
#             [0.1515, 0.1667, 0.2537, 0.1299],
#             [0.7247, 0.1397, 0.5279, 0.2939],
#             [0.8753, 0.6044, 0.2456, 0.7584],
#             [0.4997, 0.4200, 1.0000, 0.8339],
#             [0.4998, 0.6258, 1.0000, 0.7223],
#             [0.2183, 0.1981, 0.3643, 0.1500],
#             [0.1485, 0.1962, 0.2074, 0.1137],
#             [0.8787, 0.6141, 0.2397, 0.7407],
#             [0.5374, 0.2977, 0.0797, 0.2952],
#             [0.4997, 0.5288, 1.0000, 0.9040],
#             [0.4997, 0.3867, 1.0000, 0.7633],
#             [0.1645, 0.1932, 0.2159, 0.0960],
#             [0.5044, 0.6445, 0.9415, 0.6875],
#             [0.5796, 0.5137, 0.8398, 0.9414],
#             [0.6024, 0.4726, 0.7903, 0.8925],
#             [0.4998, 0.6052, 0.9999, 0.7621],
#             [0.5496, 0.3085, 0.0612, 0.3078],
#             [0.5487, 0.2843, 0.0569, 0.2800],
#             [0.7633, 0.4026, 0.4710, 0.7347],
#             [0.5832, 0.5104, 0.8332, 0.9545],
#             [0.5510, 0.2639, 0.0550, 0.2257],
#             [0.5478, 0.2814, 0.0659, 0.2433],
#             [0.5678, 0.5358, 0.8545, 0.8970],
#             [0.1705, 0.1866, 0.2025, 0.0776],
#             [0.4996, 0.4090, 1.0000, 0.8139],
#             [0.7694, 0.4063, 0.4629, 0.7101],
#             [0.6553, 0.4135, 0.6058, 0.7715]]], device='cuda:0',
#           grad_fn=<UnbindBackward>)},
#   {'pred_logits': tensor([[[-18.4498,   0.2978,  -8.7631,  ...,  -8.9758, -10.4438,   9.0008],
#             [-16.0849,  -0.4208, -11.8335,  ...,  -5.3253,  -2.6155,   9.3294],
#             [-20.2826,  -1.0078, -10.2819,  ...,  -8.2421,  -9.6290,   9.9238],
#             ...,
#             [-19.1746,  -0.7908,  -9.4164,  ...,  -8.0077, -11.2793,   9.8390],
#             [-11.9327,   2.6679,  -4.2873,  ...,  -5.8902,  -6.9141,   5.4882],
#             [-17.5627,  -0.2745, -10.5527,  ...,  -8.1684,  -9.1196,   9.1631]]],
#           device='cuda:0', grad_fn=<UnbindBackward>),
#    'pred_boxes': tensor([[[0.4963, 0.5445, 0.9942, 0.8865],
#             [0.5421, 0.2781, 0.0760, 0.2533],
#             [0.4108, 0.6219, 0.8118, 0.7276],
#             [0.5517, 0.1977, 0.0430, 0.0770],
#             [0.4995, 0.4382, 0.9999, 0.8553],
#             [0.4943, 0.5227, 0.9819, 0.9217],
#             [0.5382, 0.2748, 0.0412, 0.1983],
#             [0.1587, 0.2208, 0.2295, 0.1546],
#             [0.1871, 0.1818, 0.1528, 0.0612],
#             [0.4999, 0.2212, 0.9989, 0.4579],
#             [0.5468, 0.4982, 0.8926, 0.9749],
#             [0.4997, 0.5667, 1.0000, 0.8462],
#             [0.7685, 0.4975, 0.4604, 0.8844],
#             [0.8739, 0.6098, 0.2507, 0.7472],
#             [0.2889, 0.5964, 0.5522, 0.7881],
#             [0.1653, 0.1842, 0.2279, 0.1274],
#             [0.1219, 0.1555, 0.2506, 0.1754],
#             [0.8045, 0.1588, 0.3826, 0.3558],
#             [0.8860, 0.5971, 0.2236, 0.7397],
#             [0.4996, 0.4091, 0.9992, 0.8152],
#             [0.5000, 0.6527, 1.0000, 0.6897],
#             [0.2209, 0.1970, 0.4083, 0.1527],
#             [0.1281, 0.1907, 0.2052, 0.1085],
#             [0.8847, 0.6088, 0.2257, 0.7491],
#             [0.5406, 0.3063, 0.0827, 0.3082],
#             [0.4998, 0.5361, 1.0000, 0.8982],
#             [0.4993, 0.3972, 0.9967, 0.7874],
#             [0.1690, 0.1859, 0.2138, 0.0893],
#             [0.5021, 0.6319, 0.9898, 0.7279],
#             [0.5976, 0.5039, 0.8054, 0.9656],
#             [0.6112, 0.4658, 0.7770, 0.8954],
#             [0.4998, 0.6049, 1.0000, 0.7668],
#             [0.5478, 0.3535, 0.0653, 0.4074],
#             [0.5475, 0.3021, 0.0629, 0.3177],
#             [0.7655, 0.4297, 0.4673, 0.7725],
#             [0.5945, 0.5123, 0.8080, 0.9323],
#             [0.5498, 0.2538, 0.0519, 0.2051],
#             [0.5505, 0.2762, 0.0571, 0.2373],
#             [0.5436, 0.5056, 0.8981, 0.9541],
#             [0.1716, 0.1846, 0.1874, 0.0781],
#             [0.4996, 0.3869, 1.0000, 0.7640],
#             [0.7697, 0.4057, 0.4635, 0.7068],
#             [0.6726, 0.4482, 0.6591, 0.8778]]], device='cuda:0',
#           grad_fn=<UnbindBackward>)},
#   {'pred_logits': tensor([[[-18.9320,   0.3040, -10.0411,  ...,  -9.4447, -11.4244,   9.7100],
#             [-16.7213,  -0.9036, -11.5850,  ...,  -6.6950,  -3.1656,   9.7691],
#             [-20.2397,  -0.4994, -10.5635,  ...,  -8.0248,  -9.6426,  10.2599],
#             ...,
#             [-19.1441,  -1.1925, -10.2139,  ..., -10.5346, -11.9046,  10.5055],
#             [-12.1846,   2.5352,  -4.3859,  ...,  -6.4013,  -7.1380,   5.7433],
#             [-18.6506,   0.3276, -10.9973,  ...,  -9.2631, -10.9236,  10.0281]]],
#           device='cuda:0', grad_fn=<UnbindBackward>),
#    'pred_boxes': tensor([[[0.4953, 0.5487, 0.9960, 0.8822],
#             [0.5464, 0.2780, 0.0809, 0.2497],
#             [0.4210, 0.6139, 0.8314, 0.7522],
#             [0.5541, 0.1943, 0.0385, 0.0652],
#             [0.4995, 0.4150, 0.9999, 0.8258],
#             [0.4999, 0.5237, 0.9997, 0.9308],
#             [0.5449, 0.2712, 0.0413, 0.2063],
#             [0.1555, 0.2283, 0.2270, 0.1592],
#             [0.1847, 0.1832, 0.1593, 0.0597],
#             [0.4997, 0.3319, 0.9988, 0.6630],
#             [0.5371, 0.5085, 0.9098, 0.9632],
#             [0.4997, 0.5561, 1.0000, 0.8678],
#             [0.7721, 0.5009, 0.4551, 0.8886],
#             [0.8781, 0.6100, 0.2423, 0.7373],
#             [0.2876, 0.5939, 0.5633, 0.7901],
#             [0.1594, 0.1852, 0.2306, 0.1120],
#             [0.0453, 0.1335, 0.0927, 0.1923],
#             [0.8076, 0.1469, 0.3820, 0.3022],
#             [0.8751, 0.5736, 0.2444, 0.7130],
#             [0.4996, 0.4204, 0.9993, 0.8297],
#             [0.5006, 0.5461, 0.9920, 0.8849],
#             [0.1956, 0.1848, 0.3597, 0.1476],
#             [0.1198, 0.1889, 0.2021, 0.0990],
#             [0.8851, 0.5887, 0.2265, 0.7288],
#             [0.5093, 0.3485, 0.1301, 0.4096],
#             [0.4998, 0.5354, 1.0000, 0.8971],
#             [0.4998, 0.3943, 0.9991, 0.7871],
#             [0.1676, 0.1874, 0.2168, 0.0881],
#             [0.5058, 0.6069, 0.9734, 0.7598],
#             [0.5967, 0.5033, 0.8076, 0.9711],
#             [0.6083, 0.4863, 0.7827, 0.9079],
#             [0.4998, 0.6059, 0.9997, 0.7654],
#             [0.5336, 0.3795, 0.0859, 0.4839],
#             [0.5498, 0.3375, 0.0745, 0.3977],
#             [0.7659, 0.4771, 0.4688, 0.8670],
#             [0.5931, 0.5148, 0.8092, 0.9452],
#             [0.5545, 0.2444, 0.0488, 0.1796],
#             [0.5518, 0.2885, 0.0553, 0.2625],
#             [0.5220, 0.5139, 0.9323, 0.9384],
#             [0.1681, 0.1864, 0.2077, 0.0831],
#             [0.4996, 0.3747, 1.0000, 0.7472],
#             [0.7702, 0.4075, 0.4633, 0.7154],
#             [0.6591, 0.4844, 0.6899, 0.9476]]], device='cuda:0',
#           grad_fn=<UnbindBackward>)}]}

# %%
conv_features = conv_features[0] # feature-map
enc_attn_weights = enc_attn_weights[-1] # 마지막 encoder layer의 가중치만 사용 (256개의 값)
dec_attn_weights = dec_attn_weights[0] # 마지막 decoder layer의 가중치만 사용 (256개의 값)

# %%
#  get the shape of feature map
h, w = conv_features['0'].tensors.shape[-2:] # Nested tensor -> tensors
#     img_np = np.array(im).astype(np.float)

# %% [markdown]
# > 여기부터 Explanation

# %%
index=None
use_lrp=True # 타당성전파.
normalize_self_attention=True
applys_self_in_rule_10=True

# %%
outputs = model(img)
outputs = outputs['pred_logits'] # size : 100 x 92 (queries x classes)

# %% [markdown]
# > for one box in boxes:

# %%
(xmin, ymin, xmax, ymax)=bboxes_scaled[0]

# %%
target_index=keep.nonzero()[0]

# %%
kwargs = {"alpha": 1, 
         "target_index" : target_index}
kwargs["target_class"] = index

# %% [markdown]
# > 첫번째 클래스(+두번째)

# %%
if index == None:
    index = outputs[0, target_index, :-1].max(1)[1]

# %%
# 두번째
scd=index=outputs[0, target_index, :-1].argsort(descending=True)[0][1]

# %%
outputs.shape
# Out:
# torch.Size([1, 100, 92])

# %%
one_hot=torch.zeros_like(outputs).to(device)

# %%
one_hot[0, target_index, index]=1

# %%
one_hot_vector=one_hot.clone().detach()

# %%
one_hot = torch.sum(one_hot.cuda() * outputs) # score

# %%
model.zero_grad()

# %%
one_hot.backward(retain_graph=True)

# %% [markdown]
# > size : [1, 100, 92] --> [1, 256, 25, 34]

# %%
decoder_blocks = model.transformer.decoder.layers
encoder_blocks = model.transformer.encoder.layers

# %%
# self attn : [multihead x input x input]

## 픽셀개수
image_bboxes = encoder_blocks[0].self_attn.get_attn().shape[-1] # [8x850x850(*)]

## object 개수
queries_num = decoder_blocks[0].self_attn.get_attn().shape[-1] # [8x100x100]

# %%
# 타당성 행렬 (self and co attentions)
## 또한, 계산 자체가 attention weights랑 행해지기 때문에 device 맞춰주기
R_i_i = torch.eye(image_bboxes, image_bboxes).to(encoder_blocks[0].self_attn.get_attn().device)
R_q_q = torch.eye(queries_num, queries_num).to(decoder_blocks[0].self_attn.get_attn().device)

R_q_i = torch.eye(queries_num, image_bboxes).to(encoder_blocks[0].self_attn.get_attn().device)

# %% [markdown]
# > 타당성 전파 함수

# %%
def avg_heads(cam, grad):
    cam = cam.reshape(-1, cam.shape[-2], cam.shape[-1]) # 굳이?
    grad = grad.reshape(-1, grad.shape[-2], grad.shape[-1]) # 굳이?
    cam = grad * cam 
    cam = cam.clamp(min=0).mean(dim=0) # 음수를 제거한 다음 heads 차원을 따라 평균
    return cam

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > self attention vs multihead attention

# %% [markdown]
# 여기부터, 9월 12일 handle residual 이해하기 - apply_mm_Attention_rule 이해하기 --> generate_ours 나머지(aggregated 이해하기)... --> self_attn(transformer? layers?).get_grad_cam 이해하기 --> encoder랑 decoder self-attention이 다른 이유(encoder에는 positional embeddings이 안 들어가는가?)(혹은, 차라리 그냥 이 설명 기법 하나 다 본 다음에 DETR(TRANSFORMER in GAE)의 구조를 훑는 게 나을듯

# %%
# image self attention in encoder - 식(6) 
# 원래 handle_self_attention_image(encoder_blocks) 1줄
for blk in encoder_blocks:
    grad = blk.self_attn.get_attn_gradients().detach() # [8 x wh x wh]의 gradient(당연히 가중치랑 같음)
    if use_lrp: # 타당성 전파 시
        cam = blk.self_attn.get_attn_cam().detach() # [8 x wh x wh]의 cam(*)
    else:
        cam = blk.self_attn.get_attn().detach()
    cam = avg_heads(cam, grad)  # [wh x wh]의 averaged cam
    R_i_i += torch.matmul(cam, self.R_i_i)# [wh x wh] X [wh x wh]

# queries self attention in decoder (그 이후 mm attention)

for blk in decoder_blocks:
    
    # decoder self attention - 식 (6), (7)
    # 원래 self.handle_co_attn_self_query(blk) 
    grad = blk.self_attn.get_attn_gradients().detach()
    if use_lrp : 
        cam = blk.self_attn.get_attn_cam().detach()
    else:
        cam = blk.self_attn.get_attn().detach()
    cam = avg_heads(cam,grad)
    R_q_q_add, R_q_i_add = apply_self_attention_reules(R_q_q, R_q_i, cam) - 식 (6)(7)
    R_q_q += R_q_q_add
    R_q_i += R_q_i_add
    
    
    # encoder - decoder  - 식 (10)
    # 원래 self.handle_co_attn_query(blk) 
    
    if use_lrp:
        cam_q_i = blk.multihead_atttn.get_attn_cam().detach() # multihead
    else:
        cam_q_i = blk.multihead_attn.get_attn().detach() ##
    grad_q_i = blk.multihead_attn.get_attn_gradients().detach()
    cam_q_i = avg_heads(cam_q_i, grad_q_i)
    R_q_i += apply_mm_Attention_rules(R_q_q, R_i_i, cam_q_i, 
                                     apply_normalization=normalize_self_attention,
                                     apply_self_in_rule_10=apply_self_in_rule_10) # R
# Out:
# ModuleList(
#   (0): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (q_proj): Linear(in_features=256, out_features=256, bias=True)
#       (k_proj): Linear(in_features=256, out_features=256, bias=True)
#       (v_proj): Linear(in_features=256, out_features=256, bias=True)
#       (out_proj): Linear(in_features=256, out_features=256, bias=True)
#       (softmax): Softmax(dim=-1)
#       (einsum1): einsum()
#       (einsum2): einsum()
#     )
#     (linear1): Linear(in_features=256, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=256, bias=True)
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (activation): ReLU()
#     (add1): Add()
#     (add2): Add()
#     (clone1): Clone()
#     (clone2): Clone()
#     (clone3): Clone()
#     (clone4): Clone()
#     (wembd1): WithPosEmbd(
#       (add_pos): Add()
#     )
#   )
#   (1): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (q_proj): Linear(in_features=256, out_features=256, bias=True)
#       (k_proj): Linear(in_features=256, out_features=256, bias=True)
#       (v_proj): Linear(in_features=256, out_features=256, bias=True)
#       (out_proj): Linear(in_features=256, out_features=256, bias=True)
#       (softmax): Softmax(dim=-1)
#       (einsum1): einsum()
#       (einsum2): einsum()
#     )
#     (linear1): Linear(in_features=256, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=256, bias=True)
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (activation): ReLU()
#     (add1): Add()
#     (add2): Add()
#     (clone1): Clone()
#     (clone2): Clone()
#     (clone3): Clone()
#     (clone4): Clone()
#     (wembd1): WithPosEmbd(
#       (add_pos): Add()
#     )
#   )
#   (2): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (q_proj): Linear(in_features=256, out_features=256, bias=True)
#       (k_proj): Linear(in_features=256, out_features=256, bias=True)
#       (v_proj): Linear(in_features=256, out_features=256, bias=True)
#       (out_proj): Linear(in_features=256, out_features=256, bias=True)
#       (softmax): Softmax(dim=-1)
#       (einsum1): einsum()
#       (einsum2): einsum()
#     )
#     (linear1): Linear(in_features=256, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=256, bias=True)
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (activation): ReLU()
#     (add1): Add()
#     (add2): Add()
#     (clone1): Clone()
#     (clone2): Clone()
#     (clone3): Clone()
#     (clone4): Clone()
#     (wembd1): WithPosEmbd(
#       (add_pos): Add()
#     )
#   )
#   (3): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (q_proj): Linear(in_features=256, out_features=256, bias=True)
#       (k_proj): Linear(in_features=256, out_features=256, bias=True)
#       (v_proj): Linear(in_features=256, out_features=256, bias=True)
#       (out_proj): Linear(in_features=256, out_features=256, bias=True)
#       (softmax): Softmax(dim=-1)
#       (einsum1): einsum()
#       (einsum2): einsum()
#     )
#     (linear1): Linear(in_features=256, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=256, bias=True)
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (activation): ReLU()
#     (add1): Add()
#     (add2): Add()
#     (clone1): Clone()
#     (clone2): Clone()
#     (clone3): Clone()
#     (clone4): Clone()
#     (wembd1): WithPosEmbd(
#       (add_pos): Add()
#     )
#   )
#   (4): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (q_proj): Linear(in_features=256, out_features=256, bias=True)
#       (k_proj): Linear(in_features=256, out_features=256, bias=True)
#       (v_proj): Linear(in_features=256, out_features=256, bias=True)
#       (out_proj): Linear(in_features=256, out_features=256, bias=True)
#       (softmax): Softmax(dim=-1)
#       (einsum1): einsum()
#       (einsum2): einsum()
#     )
#     (linear1): Linear(in_features=256, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=256, bias=True)
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (activation): ReLU()
#     (add1): Add()
#     (add2): Add()
#     (clone1): Clone()
#     (clone2): Clone()
#     (clone3): Clone()
#     (clone4): Clone()
#     (wembd1): WithPosEmbd(
#       (add_pos): Add()
#     )
#   )
#   (5): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (q_proj): Linear(in_features=256, out_features=256, bias=True)
#       (k_proj): Linear(in_features=256, out_features=256, bias=True)
#       (v_proj): Linear(in_features=256, out_features=256, bias=True)
#       (out_proj): Linear(in_features=256, out_features=256, bias=True)
#       (softmax): Softmax(dim=-1)
#       (einsum1): einsum()
#       (einsum2): einsum()
#     )
#     (linear1): Linear(in_features=256, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=256, bias=True)
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.1, inplace=False)
#     (dropout2): Dropout(p=0.1, inplace=False)
#     (activation): ReLU()
#     (add1): Add()
#     (add2): Add()
#     (clone1): Clone()
#     (clone2): Clone()
#     (clone3): Clone()
#     (clone4): Clone()
#     (wembd1): WithPosEmbd(
#       (add_pos): Add()
#     )
#   )
# )

# %%
def handle_self_attention_image(self, blocks):
        for blk in blocks:
            grad = blk.self_attn.get_attn_gradients().detach() # [8 x wh x wh]의 gradient(당연히 가중치랑 같음)
            if self.use_lrp: # 타당성 전파 시
                cam = blk.self_attn.get_attn_cam().detach() # [8 x wh x wh]의 cam(*)
            else:
                cam = blk.self_attn.get_attn().detach()
            cam = avg_heads(cam, grad)  # [wh x wh]의 averaged cam
            self.R_i_i += torch.matmul(cam, self.R_i_i)# [wh x wh] X [wh x wh]

    def handle_co_attn_self_query(self, block):
        grad = block.self_attn.get_attn_gradients().detach()
        if self.use_lrp:
            cam = block.self_attn.get_attn_cam().detach()
        else:
            cam = block.self_attn.get_attn().detach()
        cam = avg_heads(cam, grad)
        R_q_q_add, R_q_i_add = apply_self_attention_rules(self.R_q_q, self.R_q_i, cam)
        self.R_q_q += R_q_q_add
        self.R_q_i += R_q_i_add

    def handle_co_attn_query(self, block):
        if self.use_lrp:
            cam_q_i = block.multihead_attn.get_attn_cam().detach()
        else:
            cam_q_i = block.multihead_attn.get_attn().detach()
        grad_q_i = block.multihead_attn.get_attn_gradients().detach()
        cam_q_i = avg_heads(cam_q_i, grad_q_i)
        self.R_q_i += apply_mm_attention_rules(self.R_q_q, self.R_i_i, cam_q_i,
                                               apply_normalization=self.normalize_self_attention, # R_qq, R_ii 정규화
                                               apply_self_in_rule_10=self.apply_self_in_rule_10) # R_sq 대신 cam_sq (*)

# %%
handle_residual(R_q_q)
# Out:
# tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]], device='cuda:0')

# %%
# 식 (6), (7)
# 증가분을 반환합니다(위 식의 뒤쪽 항)
def apply_self_attention_rules(R_ss, R_sq, cam_ss):
    R_sq_addition = torch.matmul(cam_ss, R_sq)
    R_ss_addition = torch.matmul(cam_ss, R_ss)
    return R_ss_addition, R_sq_addition

# 식 (10)
# bi-modal에 대한 aggregation rule
def apply_mm_attention_rules(R_ss, R_qq, cam_sq, apply_normalization=True,
                            apply_self_in_rule_10=True):
    R_ss_normalized = R_ss
    R_qq_normalized = R_qq
    
    if apply_normalization:
        R_ss_normalized = handle_residual(R_ss)
        R_qq_normalized = handle_residual(R_qq)
    R_sq_addition = torch.matmul(R_ss_normalized.t(), torch.matmul(cam_sq, R_qq_normalized))
    if not apply_self_in_rule_10:
        R_sq_addition = cam_sq
    R_sq_addition[torch.isnan(R_sq_addition)] = 0
    return R_sq_addition

# normalization- eq. 8+9
def handle_residual(orig_self_attention):
    self_attention = orig_self_attention.clone()
    diag_idx = range(self_attention.shape[-1])
    self_attention -= torch.eye(self_attention.shape[-1]).to(self_attention.device)
    assert self_attention[diag_idx, diag_idx].min() >= 0
    self_attention = self_attention / self_attention.sum(dim=-1, keepdim=True)
    self_attention += torch.eye(self_attention.shape[-1]).to(self_attention.device)
    return self_attention

# %% [markdown]
# 시각화

# %%
fig, axs = plt.subplots(ncols=len(bboxes_scaled), nrows=2, figsize=(22,7))

# object queries는 100차원(default)이기 때문에 그 중에 
# 0.7(default) 이상의 신뢰도를 보이는 query만을 사용해야 한다. 
for idx, ax_i, (xmin, ymin, xmax, ymax) in zip(keep.nonzero(), axs.T, bboxes_scaled):
    ax = ax_i[0]
    cam = gen.generate_ours(img, idx, use_lrp=False)
    cam = (cam - cam.min()) / (cam.max() - cam.min()) # 점수 정규화
    cmap = plt.cm.get_cmap('Blues').reversed()
    ax.imshow(cam.view(h, w).data.cpu().numpy(), cmap=cmap)
    ax.axis('off')
    ax.set_title(f'query id: {idx.item()}')
    ax = ax_i[1]
    ax.imshow(im)
    ax.add_patch(plt.Rectangle((xmin.detach(), ymin.detach()), 
                              xmax.detach() - xmin.detach(),
                               ymax.detach() - ymin.detach(), 
                               fill=False, color='blue', linewidth=3))
    ax.axis('off')
    ax.set_title(CLASSES[probas[idx].argmax()])

id_str = '' if image_id == None else image_id
fig.tight_layout()
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3966128/2086722644.py in <module>
#       3 for idx, ax_i, (xmin, ymin, xmax, ymax) in zip(keep.nonzero(), axs.T, bboxes_scaled):
#       4     ax = ax_i[0]
# ----> 5     cam = gen.generate_ours(img, idx, use_lrp=False)
#       6     cam = (cam - cam.min()) / (cam.max() - cam.min()) # 점수 정규화
#       7     cmap = plt.cm.get_cmap('Blues').reversed()
#
# ~/jsp/xod/Transformer-MM-Explainability/DETR/modules/ExplanationGenerator.py in generate_ours(self, img, target_index, index, use_lrp, normalize_self_attention, apply_self_in_rule_10)
#     144         self.normalize_self_attention = normalize_self_attention
#     145         self.apply_self_in_rule_10 = apply_self_in_rule_10
# --> 146         outputs = self.model(img)
#     147         outputs = outputs['pred_logits']
#     148         kwargs = {"alpha": 1,
#
# ~/.conda/envs/jsp_xod/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/jsp/xod/Transformer-MM-Explainability/DETR/models/detr.py in forward(self, samples)
#      61         if isinstance(samples, (list, torch.Tensor)):
#      62             samples = nested_tensor_from_tensor_list(samples)
# ---> 63         features, pos = self.backbone(samples)
#      64
#      65         src, mask = features[-1].decompose()
#
# ~/.conda/envs/jsp_xod/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/jsp/xod/Transformer-MM-Explainability/DETR/models/backbone.py in forward(self, tensor_list)
#      99
#     100     def forward(self, tensor_list: NestedTensor):
# --> 101         xs = self[0](tensor_list)
#     102         out: List[NestedTensor] = []
#     103         pos = []
#
# ~/.conda/envs/jsp_xod/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     729                 _global_forward_hooks.values(),
#     730                 self._forward_hooks.values()):
# --> 731             hook_result = hook(self, input, result)
#     732             if hook_result is not None:
#     733                 result = hook_result
#
# /tmp/ipykernel_3966128/601286181.py in <lambda>(self, input, output)
#       7     # real bacbkone (backbone[-1] : positional embeddings)
#       8     model.backbone[-2].register_forward_hook(
# ----> 9     lambda self, input, output: conv_features.append(output)
#      10     ),
#      11
#
# AttributeError: 'dict' object has no attribute 'append'

# %% [markdown]
# 2021년 9월 11~12 할 것
# 1. self_attn layer의 method get_attn_cam <--
# 2. encoder는 positional embeddings 안 들어가나 ? 이거 DETR에서 확인(원본과 비교해야 할 수도)
